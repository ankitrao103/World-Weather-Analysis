# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(-90,90,size=2000)
lngs=np.random.uniform(-180,180,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country":city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | awjilah
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | namibe
# Processing Record 10 of Set 1 | genhe
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | bagdarin
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | ossora
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | iquitos
# Processing Record 17 of Set 1 | faanui
# Processing Record 18 of Set 1 | muncar
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | mariinsk
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | feijo
# Processing Record 25 of Set 1 | buraydah
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | dunedin
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 1 | praia da vitoria
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | ostrovnoy
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | ust-ilimsk
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | burica
# City not found. Skipping...
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | buncrana
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | tulsipur
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | kariba
# Processing Record 4 of Set 2 | denpasar
# Processing Record 5 of Set 2 | trairi
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | pilao arcado
# City not found. Skipping...
# Processing Record 8 of Set 2 | camacha
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | caravelas
# Processing Record 12 of Set 2 | viedma
# Processing Record 13 of Set 2 | huazhou
# Processing Record 14 of Set 2 | hualmay
# Processing Record 15 of Set 2 | manzhouli
# Processing Record 16 of Set 2 | road town
# Processing Record 17 of Set 2 | hellvik
# Processing Record 18 of Set 2 | richards bay
# Processing Record 19 of Set 2 | acari
# Processing Record 20 of Set 2 | talara
# Processing Record 21 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 2 | palmares do sul
# Processing Record 23 of Set 2 | sulangan
# Processing Record 24 of Set 2 | san patricio
# Processing Record 25 of Set 2 | la libertad
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | touros
# Processing Record 28 of Set 2 | rio grande
# Processing Record 29 of Set 2 | quatre cocos
# Processing Record 30 of Set 2 | jimeta
# Processing Record 31 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | karratha
# Processing Record 34 of Set 2 | novyy urengoy
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | fairhope
# Processing Record 38 of Set 2 | alofi
# Processing Record 39 of Set 2 | mufulira
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | prainha
# Processing Record 42 of Set 2 | oranjemund
# Processing Record 43 of Set 2 | margate
# Processing Record 44 of Set 2 | faya
# Processing Record 45 of Set 2 | culipapa
# City not found. Skipping...
# Processing Record 46 of Set 2 | srednekolymsk
# Processing Record 47 of Set 2 | conde
# Processing Record 48 of Set 2 | avera
# Processing Record 49 of Set 2 | asfi
# Processing Record 50 of Set 2 | hovd
# Processing Record 1 of Set 3 | tamiahua
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | pak phanang
# Processing Record 4 of Set 3 | te anau
# Processing Record 5 of Set 3 | konch
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | hobyo
# Processing Record 8 of Set 3 | kimbe
# Processing Record 9 of Set 3 | xining
# Processing Record 10 of Set 3 | cayenne
# Processing Record 11 of Set 3 | loandjili
# Processing Record 12 of Set 3 | alamos
# Processing Record 13 of Set 3 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 14 of Set 3 | luau
# Processing Record 15 of Set 3 | belaya gora
# Processing Record 16 of Set 3 | la ronge
# Processing Record 17 of Set 3 | nanortalik
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | cockburn town
# Processing Record 20 of Set 3 | kholodnyy
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | ostersund
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | asau
# Processing Record 27 of Set 3 | camabatela
# Processing Record 28 of Set 3 | tikrit
# Processing Record 29 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 3 | puerto baquerizo moreno
# Processing Record 31 of Set 3 | dargaville
# Processing Record 32 of Set 3 | zheleznodorozhnyy
# Processing Record 33 of Set 3 | sur
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | doctor juan leon mallorquin
# Processing Record 36 of Set 3 | gravelbourg
# Processing Record 37 of Set 3 | brive-la-gaillarde
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | krabi
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | pisco
# Processing Record 45 of Set 3 | lakselv
# Processing Record 46 of Set 3 | ekibastuz
# Processing Record 47 of Set 3 | husavik
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | noumea
# Processing Record 50 of Set 3 | yarkovo
# Processing Record 1 of Set 4 | bay roberts
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | inhambane
# Processing Record 4 of Set 4 | thurles
# Processing Record 5 of Set 4 | danville
# Processing Record 6 of Set 4 | tazovskiy
# Processing Record 7 of Set 4 | kavaratti
# Processing Record 8 of Set 4 | lata
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | dawei
# Processing Record 13 of Set 4 | broome
# Processing Record 14 of Set 4 | inirida
# Processing Record 15 of Set 4 | hollola
# Processing Record 16 of Set 4 | teya
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | uribia
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | gambo
# Processing Record 22 of Set 4 | tchibanga
# Processing Record 23 of Set 4 | kudahuvadhoo
# Processing Record 24 of Set 4 | palmer
# Processing Record 25 of Set 4 | prince rupert
# Processing Record 26 of Set 4 | manchester
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | shache
# Processing Record 29 of Set 4 | ocean city
# Processing Record 30 of Set 4 | najran
# Processing Record 31 of Set 4 | baykit
# Processing Record 32 of Set 4 | ancud
# Processing Record 33 of Set 4 | maromitsa
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | dubti
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | qasigiannguit
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | turtas
# Processing Record 41 of Set 4 | corinto
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 4 | coihaique
# Processing Record 48 of Set 4 | jining
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 5 | tasca
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | sao joao da barra
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | skara
# Processing Record 9 of Set 5 | yumen
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | port-gentil
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | monastyrshchina
# Processing Record 15 of Set 5 | olinda
# Processing Record 16 of Set 5 | waw
# Processing Record 17 of Set 5 | qixingtai
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | naftalan
# Processing Record 20 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 5 | okhotsk
# Processing Record 22 of Set 5 | celestun
# Processing Record 23 of Set 5 | olga
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | rabat
# Processing Record 26 of Set 5 | nabire
# Processing Record 27 of Set 5 | severo-kurilsk
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | mahebourg
# Processing Record 30 of Set 5 | estelle
# Processing Record 31 of Set 5 | pangnirtung
# Processing Record 32 of Set 5 | manaure
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | iskateley
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | saskylakh
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | hokitika
# Processing Record 39 of Set 5 | tadepallegudem
# Processing Record 40 of Set 5 | kurchum
# Processing Record 41 of Set 5 | ullapool
# Processing Record 42 of Set 5 | rafsanjan
# Processing Record 43 of Set 5 | honiara
# Processing Record 44 of Set 5 | pangoa
# Processing Record 45 of Set 5 | aykhal
# Processing Record 46 of Set 5 | lovozero
# Processing Record 47 of Set 5 | sioux lookout
# Processing Record 48 of Set 5 | mallaig
# Processing Record 49 of Set 5 | candeias
# Processing Record 50 of Set 5 | yar-sale
# Processing Record 1 of Set 6 | andenes
# Processing Record 2 of Set 6 | hamilton
# Processing Record 3 of Set 6 | pemberton
# Processing Record 4 of Set 6 | sumbe
# Processing Record 5 of Set 6 | tual
# Processing Record 6 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 7 of Set 6 | port macquarie
# Processing Record 8 of Set 6 | bandarbeyla
# Processing Record 9 of Set 6 | port hedland
# Processing Record 10 of Set 6 | manokwari
# Processing Record 11 of Set 6 | muros
# Processing Record 12 of Set 6 | egvekinot
# Processing Record 13 of Set 6 | bathsheba
# Processing Record 14 of Set 6 | swan hill
# Processing Record 15 of Set 6 | grobina
# Processing Record 16 of Set 6 | ibresi
# Processing Record 17 of Set 6 | chamrajnagar
# Processing Record 18 of Set 6 | lanzhou
# Processing Record 19 of Set 6 | charters towers
# Processing Record 20 of Set 6 | taltal
# Processing Record 21 of Set 6 | portland
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | vestmannaeyjar
# Processing Record 24 of Set 6 | goderich
# Processing Record 25 of Set 6 | huarmey
# Processing Record 26 of Set 6 | piura
# Processing Record 27 of Set 6 | vaitape
# Processing Record 28 of Set 6 | saint-joseph
# Processing Record 29 of Set 6 | pevek
# Processing Record 30 of Set 6 | katobu
# Processing Record 31 of Set 6 | byron bay
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | chenzhou
# Processing Record 35 of Set 6 | ures
# Processing Record 36 of Set 6 | coruripe
# Processing Record 37 of Set 6 | le port
# Processing Record 38 of Set 6 | san borja
# Processing Record 39 of Set 6 | toungoo
# City not found. Skipping...
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | nowy targ
# Processing Record 43 of Set 6 | olsztyn
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | tashtagol
# Processing Record 46 of Set 6 | rawson
# Processing Record 47 of Set 6 | thompson
# Processing Record 48 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 6 | pingdu
# Processing Record 50 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 7 | nambucca heads
# Processing Record 2 of Set 7 | bubaque
# Processing Record 3 of Set 7 | vikulovo
# Processing Record 4 of Set 7 | chuy
# Processing Record 5 of Set 7 | staryy nadym
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | tura
# Processing Record 8 of Set 7 | edson
# Processing Record 9 of Set 7 | terrace
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | kennett
# Processing Record 13 of Set 7 | beloha
# Processing Record 14 of Set 7 | isla mujeres
# Processing Record 15 of Set 7 | atotonilco el alto
# Processing Record 16 of Set 7 | matucana
# Processing Record 17 of Set 7 | unye
# City not found. Skipping...
# Processing Record 18 of Set 7 | ankang
# Processing Record 19 of Set 7 | nobres
# Processing Record 20 of Set 7 | altamira
# Processing Record 21 of Set 7 | belmonte
# Processing Record 22 of Set 7 | abu samrah
# Processing Record 23 of Set 7 | sola
# Processing Record 24 of Set 7 | chapais
# Processing Record 25 of Set 7 | fairbanks
# Processing Record 26 of Set 7 | vostok
# Processing Record 27 of Set 7 | lompoc
# Processing Record 28 of Set 7 | bambous virieux
# Processing Record 29 of Set 7 | thung song
# Processing Record 30 of Set 7 | sao pedro do sul
# Processing Record 31 of Set 7 | peace river
# Processing Record 32 of Set 7 | benguela
# Processing Record 33 of Set 7 | dicabisagan
# Processing Record 34 of Set 7 | rafai
# Processing Record 35 of Set 7 | tiznit
# Processing Record 36 of Set 7 | biloela
# Processing Record 37 of Set 7 | beringovskiy
# Processing Record 38 of Set 7 | gamba
# Processing Record 39 of Set 7 | kungurtug
# Processing Record 40 of Set 7 | airai
# Processing Record 41 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 7 | dusti
# Processing Record 43 of Set 7 | sieghartskirchen
# Processing Record 44 of Set 7 | satuk
# Processing Record 45 of Set 7 | winnemucca
# Processing Record 46 of Set 7 | moroni
# Processing Record 47 of Set 7 | ilhabela
# Processing Record 48 of Set 7 | ulladulla
# Processing Record 49 of Set 7 | bani
# Processing Record 50 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 8 | puerto ayacucho
# Processing Record 2 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 8 | iwaki
# Processing Record 4 of Set 8 | inawashiro
# Processing Record 5 of Set 8 | lawang
# Processing Record 6 of Set 8 | rawlins
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | bengkulu
# Processing Record 9 of Set 8 | salinas
# Processing Record 10 of Set 8 | lasa
# Processing Record 11 of Set 8 | elverum
# Processing Record 12 of Set 8 | lermontovka
# Processing Record 13 of Set 8 | stokmarknes
# Processing Record 14 of Set 8 | berdigestyakh
# Processing Record 15 of Set 8 | juneau
# Processing Record 16 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 8 | raudeberg
# Processing Record 18 of Set 8 | hasaki
# Processing Record 19 of Set 8 | pires do rio
# Processing Record 20 of Set 8 | jabinyanah
# Processing Record 21 of Set 8 | jiaojiang
# Processing Record 22 of Set 8 | yarovoye
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 25 of Set 8 | mason city
# Processing Record 26 of Set 8 | zinder
# Processing Record 27 of Set 8 | jalor
# Processing Record 28 of Set 8 | kawalu
# Processing Record 29 of Set 8 | methven
# Processing Record 30 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 8 | asyut
# Processing Record 32 of Set 8 | maumere
# Processing Record 33 of Set 8 | almaznyy
# Processing Record 34 of Set 8 | banda aceh
# Processing Record 35 of Set 8 | leshukonskoye
# Processing Record 36 of Set 8 | northam
# Processing Record 37 of Set 8 | meulaboh
# Processing Record 38 of Set 8 | narsaq
# Processing Record 39 of Set 8 | isiro
# Processing Record 40 of Set 8 | ternate
# Processing Record 41 of Set 8 | jiazi
# Processing Record 42 of Set 8 | ayagoz
# Processing Record 43 of Set 8 | verrettes
# Processing Record 44 of Set 8 | san lawrenz
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | cabo san lucas
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | schattdorf
# Processing Record 49 of Set 8 | wonthaggi
# Processing Record 50 of Set 8 | qena
# Processing Record 1 of Set 9 | abapo
# Processing Record 2 of Set 9 | fortuna
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 5 of Set 9 | lixourion
# Processing Record 6 of Set 9 | mosetse
# Processing Record 7 of Set 9 | santa cruz
# Processing Record 8 of Set 9 | manoel urbano
# Processing Record 9 of Set 9 | comodoro rivadavia
# Processing Record 10 of Set 9 | roma
# Processing Record 11 of Set 9 | luba
# Processing Record 12 of Set 9 | maunabo
# Processing Record 13 of Set 9 | cumra
# Processing Record 14 of Set 9 | kenai
# Processing Record 15 of Set 9 | tilichiki
# Processing Record 16 of Set 9 | nome
# Processing Record 17 of Set 9 | kalmunai
# Processing Record 18 of Set 9 | yeppoon
# Processing Record 19 of Set 9 | mildura
# Processing Record 20 of Set 9 | ranong
# Processing Record 21 of Set 9 | acarau
# Processing Record 22 of Set 9 | tautira
# Processing Record 23 of Set 9 | roseland
# Processing Record 24 of Set 9 | uyuni
# Processing Record 25 of Set 9 | kameshkovo
# Processing Record 26 of Set 9 | baghdad
# Processing Record 27 of Set 9 | krasnyy chikoy
# Processing Record 28 of Set 9 | ukiah
# Processing Record 29 of Set 9 | moranbah
# Processing Record 30 of Set 9 | north bend
# Processing Record 31 of Set 9 | chumphon
# Processing Record 32 of Set 9 | haines junction
# Processing Record 33 of Set 9 | catamarca
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | tucupita
# Processing Record 36 of Set 9 | puerto leguizamo
# Processing Record 37 of Set 9 | sept-iles
# Processing Record 38 of Set 9 | buta
# Processing Record 39 of Set 9 | roald
# Processing Record 40 of Set 9 | ligayan
# Processing Record 41 of Set 9 | hachinohe
# Processing Record 42 of Set 9 | bandrele
# Processing Record 43 of Set 9 | bethanien
# Processing Record 44 of Set 9 | zaozerne
# Processing Record 45 of Set 9 | concepcion del oro
# Processing Record 46 of Set 9 | makakilo city
# Processing Record 47 of Set 9 | zuya
# Processing Record 48 of Set 9 | gizo
# Processing Record 49 of Set 9 | tutoia
# Processing Record 50 of Set 9 | bonthe
# Processing Record 1 of Set 10 | mookane
# Processing Record 2 of Set 10 | sibolga
# Processing Record 3 of Set 10 | college
# Processing Record 4 of Set 10 | grand gaube
# Processing Record 5 of Set 10 | bani walid
# Processing Record 6 of Set 10 | puri
# Processing Record 7 of Set 10 | saint-augustin
# Processing Record 8 of Set 10 | taoudenni
# Processing Record 9 of Set 10 | portobelo
# Processing Record 10 of Set 10 | kortkeros
# Processing Record 11 of Set 10 | mehamn
# Processing Record 12 of Set 10 | polunochnoye
# Processing Record 13 of Set 10 | christchurch
# Processing Record 14 of Set 10 | kayerkan
# Processing Record 15 of Set 10 | ducheng
# Processing Record 16 of Set 10 | carnot
# Processing Record 17 of Set 10 | belyye berega
# Processing Record 18 of Set 10 | tamala
# Processing Record 19 of Set 10 | berberati
# Processing Record 20 of Set 10 | port hueneme
# Processing Record 21 of Set 10 | liuhe
# Processing Record 22 of Set 10 | dingli
# Processing Record 23 of Set 10 | kuvandyk
# Processing Record 24 of Set 10 | guerrero negro
# Processing Record 25 of Set 10 | souillac
# Processing Record 26 of Set 10 | auki
# Processing Record 27 of Set 10 | xiangdong
# City not found. Skipping...
# Processing Record 28 of Set 10 | dalby
# Processing Record 29 of Set 10 | longyearbyen
# Processing Record 30 of Set 10 | nizwa
# Processing Record 31 of Set 10 | samarai
# Processing Record 32 of Set 10 | hambantota
# Processing Record 33 of Set 10 | khor
# Processing Record 34 of Set 10 | chakwal
# Processing Record 35 of Set 10 | hukuntsi
# Processing Record 36 of Set 10 | hearst
# Processing Record 37 of Set 10 | araouane
# Processing Record 38 of Set 10 | mujiayingzi
# Processing Record 39 of Set 10 | voh
# Processing Record 40 of Set 10 | dejen
# Processing Record 41 of Set 10 | alexandria
# Processing Record 42 of Set 10 | nenjiang
# Processing Record 43 of Set 10 | gat
# Processing Record 44 of Set 10 | vanavara
# Processing Record 45 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 10 | bhachau
# Processing Record 47 of Set 10 | grand terrace
# Processing Record 48 of Set 10 | porto novo
# Processing Record 49 of Set 10 | shebunino
# Processing Record 50 of Set 10 | solwezi
# Processing Record 1 of Set 11 | port hardy
# Processing Record 2 of Set 11 | cherskiy
# Processing Record 3 of Set 11 | nhulunbuy
# Processing Record 4 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 11 | ilulissat
# Processing Record 6 of Set 11 | camana
# Processing Record 7 of Set 11 | chimbote
# Processing Record 8 of Set 11 | godfrey
# Processing Record 9 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 11 | severo-yeniseyskiy
# Processing Record 11 of Set 11 | fare
# Processing Record 12 of Set 11 | les cayes
# Processing Record 13 of Set 11 | morwell
# Processing Record 14 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 11 | atar
# Processing Record 16 of Set 11 | batagay-alyta
# Processing Record 17 of Set 11 | vardo
# Processing Record 18 of Set 11 | rochegda
# Processing Record 19 of Set 11 | gorom-gorom
# Processing Record 20 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 11 | kharan
# Processing Record 23 of Set 11 | brae
# Processing Record 24 of Set 11 | jalu
# Processing Record 25 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 11 | plonsk
# Processing Record 27 of Set 11 | kozhva
# Processing Record 28 of Set 11 | obigarm
# Processing Record 29 of Set 11 | nelson bay
# Processing Record 30 of Set 11 | banfora
# Processing Record 31 of Set 11 | seoul
# Processing Record 32 of Set 11 | fuerte olimpo
# Processing Record 33 of Set 11 | beziers
# Processing Record 34 of Set 11 | opuwo
# Processing Record 35 of Set 11 | havre-saint-pierre
# Processing Record 36 of Set 11 | zhezkazgan
# Processing Record 37 of Set 11 | clyde river
# Processing Record 38 of Set 11 | springbok
# Processing Record 39 of Set 11 | burnie
# Processing Record 40 of Set 11 | taunggyi
# Processing Record 41 of Set 11 | villa carlos paz
# Processing Record 42 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 43 of Set 11 | gberia fotombu
# Processing Record 44 of Set 11 | dongobesh
# Processing Record 45 of Set 11 | shelburne
# Processing Record 46 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 11 | amantea
# Processing Record 48 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 11 | tutin
# Processing Record 50 of Set 11 | atasu
# Processing Record 1 of Set 12 | mandera
# Processing Record 2 of Set 12 | graham
# Processing Record 3 of Set 12 | saint-francois
# Processing Record 4 of Set 12 | kununurra
# Processing Record 5 of Set 12 | mao
# Processing Record 6 of Set 12 | riyadh
# Processing Record 7 of Set 12 | arak
# Processing Record 8 of Set 12 | sawakin
# Processing Record 9 of Set 12 | strezhevoy
# Processing Record 10 of Set 12 | wawa
# Processing Record 11 of Set 12 | vermillion
# Processing Record 12 of Set 12 | necochea
# Processing Record 13 of Set 12 | vertou
# Processing Record 14 of Set 12 | bermeo
# Processing Record 15 of Set 12 | shingu
# Processing Record 16 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 17 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 12 | ambunti
# Processing Record 19 of Set 12 | krasnoselkup
# Processing Record 20 of Set 12 | camapua
# Processing Record 21 of Set 12 | boyle
# Processing Record 22 of Set 12 | illela
# Processing Record 23 of Set 12 | liwale
# Processing Record 24 of Set 12 | nsanje
# Processing Record 25 of Set 12 | dali
# Processing Record 26 of Set 12 | thinadhoo
# Processing Record 27 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 12 | cairns
# Processing Record 29 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 12 | trimbak
# Processing Record 31 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 12 | burhar
# Processing Record 33 of Set 12 | portree
# Processing Record 34 of Set 12 | tangjiazhuang
# Processing Record 35 of Set 12 | arlit
# Processing Record 36 of Set 12 | ojinaga
# Processing Record 37 of Set 12 | bali
# Processing Record 38 of Set 12 | sangar
# Processing Record 39 of Set 12 | catumbela
# Processing Record 40 of Set 12 | kadhan
# Processing Record 41 of Set 12 | poum
# Processing Record 42 of Set 12 | antigonish
# Processing Record 43 of Set 12 | lithakia
# Processing Record 44 of Set 12 | timra
# Processing Record 45 of Set 12 | nagapattinam
# Processing Record 46 of Set 12 | tingo maria
# Processing Record 47 of Set 12 | novobirilyussy
# Processing Record 48 of Set 12 | aquiraz
# Processing Record 49 of Set 12 | carahue
# Processing Record 50 of Set 12 | olafsvik
# Processing Record 1 of Set 13 | ugoofaaru
# Processing Record 2 of Set 13 | minab
# Processing Record 3 of Set 13 | tromso
# Processing Record 4 of Set 13 | santa teresa
# Processing Record 5 of Set 13 | ahipara
# Processing Record 6 of Set 13 | aginskoye
# Processing Record 7 of Set 13 | atambua
# Processing Record 8 of Set 13 | chudniv
# Processing Record 9 of Set 13 | shizukuishi
# Processing Record 10 of Set 13 | qaqortoq
# Processing Record 11 of Set 13 | arys
# Processing Record 12 of Set 13 | ribas do rio pardo
# Processing Record 13 of Set 13 | evensk
# Processing Record 14 of Set 13 | boyolangu
# Processing Record 15 of Set 13 | waipawa
# Processing Record 16 of Set 13 | warman
# Processing Record 17 of Set 13 | piotrkow trybunalski
# Processing Record 18 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 13 | santa maria
# Processing Record 20 of Set 13 | bykovo
# Processing Record 21 of Set 13 | astoria
# Processing Record 22 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 13 | penzance
# Processing Record 24 of Set 13 | hofn
# Processing Record 25 of Set 13 | skibbereen
# Processing Record 26 of Set 13 | bhadrachalam
# Processing Record 27 of Set 13 | barabai
# Processing Record 28 of Set 13 | diffa
# Processing Record 29 of Set 13 | dungarvan
# Processing Record 30 of Set 13 | neuquen
# Processing Record 31 of Set 13 | petatlan
# Processing Record 32 of Set 13 | gopalpur
# Processing Record 33 of Set 13 | craig
# Processing Record 34 of Set 13 | behshahr
# Processing Record 35 of Set 13 | fort dodge
# Processing Record 36 of Set 13 | shakawe
# Processing Record 37 of Set 13 | requena
# Processing Record 38 of Set 13 | ahuimanu
# Processing Record 39 of Set 13 | bhaderwah
# Processing Record 40 of Set 13 | veraval
# Processing Record 41 of Set 13 | bystryy istok
# Processing Record 42 of Set 13 | cabedelo
# Processing Record 43 of Set 13 | vila franca do campo
# Processing Record 44 of Set 13 | laela
# Processing Record 45 of Set 13 | setermoen
# Processing Record 46 of Set 13 | grand-lahou
# Processing Record 47 of Set 13 | half moon bay
# Processing Record 48 of Set 13 | amiens
# Processing Record 49 of Set 13 | morwa
# Processing Record 50 of Set 13 | grenville
# Processing Record 1 of Set 14 | harindanga
# Processing Record 2 of Set 14 | riohacha
# Processing Record 3 of Set 14 | srandakan
# Processing Record 4 of Set 14 | pundaguitan
# Processing Record 5 of Set 14 | pacifica
# Processing Record 6 of Set 14 | mahajanga
# Processing Record 7 of Set 14 | chicama
# Processing Record 8 of Set 14 | pascagoula
# Processing Record 9 of Set 14 | alice springs
# Processing Record 10 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 11 of Set 14 | detmold
# Processing Record 12 of Set 14 | helena
# Processing Record 13 of Set 14 | aklavik
# Processing Record 14 of Set 14 | vila velha
# Processing Record 15 of Set 14 | flinders
# Processing Record 16 of Set 14 | smolenka
# Processing Record 17 of Set 14 | nalut
# Processing Record 18 of Set 14 | sobolevo
# Processing Record 19 of Set 14 | porto walter
# Processing Record 20 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 14 | yanam
# Processing Record 22 of Set 14 | fort nelson
# Processing Record 23 of Set 14 | tucuma
# Processing Record 24 of Set 14 | lorengau
# Processing Record 25 of Set 14 | valreas
# Processing Record 26 of Set 14 | black diamond
# Processing Record 27 of Set 14 | hervey bay
# Processing Record 28 of Set 14 | cherusti
# Processing Record 29 of Set 14 | portknockie
# Processing Record 30 of Set 14 | ngunguru
# Processing Record 31 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 14 | young
# Processing Record 33 of Set 14 | sisimiut
# Processing Record 34 of Set 14 | san vicente
# Processing Record 35 of Set 14 | chadan
# Processing Record 36 of Set 14 | upington
# Processing Record 37 of Set 14 | kodinsk
# Processing Record 38 of Set 14 | seydi
# Processing Record 39 of Set 14 | barranca
# Processing Record 40 of Set 14 | lagoa
# Processing Record 41 of Set 14 | velsk
# Processing Record 42 of Set 14 | manohar thana
# Processing Record 43 of Set 14 | saint anthony
# Processing Record 44 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 45 of Set 14 | mogadishu
# Processing Record 46 of Set 14 | russell
# Processing Record 47 of Set 14 | marystown
# Processing Record 48 of Set 14 | huoqiu
# Processing Record 49 of Set 14 | kansanshi
# Processing Record 50 of Set 14 | inta
# Processing Record 1 of Set 15 | durban
# Processing Record 2 of Set 15 | muroto
# Processing Record 3 of Set 15 | marsabit
# Processing Record 4 of Set 15 | chontalpa
# Processing Record 5 of Set 15 | henties bay
# Processing Record 6 of Set 15 | sao gabriel da cachoeira
# Processing Record 7 of Set 15 | yeniseysk
# Processing Record 8 of Set 15 | hastings
# Processing Record 9 of Set 15 | adrar
# Processing Record 10 of Set 15 | sao jose da coroa grande
# Processing Record 11 of Set 15 | bilma
# Processing Record 12 of Set 15 | geelong
# Processing Record 13 of Set 15 | nouakchott
# Processing Record 14 of Set 15 | kyra
# Processing Record 15 of Set 15 | abha
# Processing Record 16 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 15 | nizhniy kuranakh
# Processing Record 18 of Set 15 | sindhnur
# Processing Record 19 of Set 15 | kundiawa
# Processing Record 20 of Set 15 | carrollton
# Processing Record 21 of Set 15 | buenos aires
# Processing Record 22 of Set 15 | mombetsu
# Processing Record 23 of Set 15 | mandalgovi
# Processing Record 24 of Set 15 | jati
# Processing Record 25 of Set 15 | carballo
# Processing Record 26 of Set 15 | paamiut
# Processing Record 27 of Set 15 | ewa beach
# Processing Record 28 of Set 15 | pasni
# Processing Record 29 of Set 15 | miri
# Processing Record 30 of Set 15 | berlevag
# Processing Record 31 of Set 15 | lourdes
# Processing Record 32 of Set 15 | kidal
# Processing Record 33 of Set 15 | inongo
# Processing Record 34 of Set 15 | ust-tsilma
# Processing Record 35 of Set 15 | jumla
# Processing Record 36 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 15 | anloga
# Processing Record 38 of Set 15 | farafangana
# Processing Record 39 of Set 15 | kahului
# Processing Record 40 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 15 | ketchikan
# Processing Record 42 of Set 15 | ailigandi
# Processing Record 43 of Set 15 | mpongwe
# Processing Record 44 of Set 15 | ulaanbaatar
# Processing Record 45 of Set 15 | ambon
# Processing Record 46 of Set 15 | deputatskiy
# Processing Record 47 of Set 15 | pitimbu
# Processing Record 48 of Set 15 | kautokeino
# Processing Record 49 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 15 | norrtalje
# Processing Record 1 of Set 16 | pedernales
# Processing Record 2 of Set 16 | altamont
# Processing Record 3 of Set 16 | kaeo
# Processing Record 4 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 16 | guangshui
# Processing Record 6 of Set 16 | sorland
# Processing Record 7 of Set 16 | quixeramobim
# Processing Record 8 of Set 16 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 16 | san policarpo
# Processing Record 10 of Set 16 | markapur
# Processing Record 11 of Set 16 | musenita
# Processing Record 12 of Set 16 | bonavista
# Processing Record 13 of Set 16 | lethem
# Processing Record 14 of Set 16 | agadez
# Processing Record 15 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 16 | carutapera
# Processing Record 17 of Set 16 | smithers
# Processing Record 18 of Set 16 | wadena
# Processing Record 19 of Set 16 | huzhou
# Processing Record 20 of Set 16 | wyndham
# Processing Record 21 of Set 16 | kashi
# Processing Record 22 of Set 16 | prieska
# Processing Record 23 of Set 16 | joutseno
# Processing Record 24 of Set 16 | maldonado
# Processing Record 25 of Set 16 | bellevue
# Processing Record 26 of Set 16 | kanker
# Processing Record 27 of Set 16 | san angelo
# Processing Record 28 of Set 16 | luanda
# Processing Record 29 of Set 16 | harper
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown  42.0970  -79.2353     33.03        66         100
# 1  Punta Arenas -53.1500  -70.9167     44.71        70           0
# 2       Awjilah  29.1081   21.2869     70.34        24         100
# 3     Busselton -33.6500  115.3333     69.62        82          99
# 4        Castro -24.7911  -50.0119     55.13        98         100
#
#    Wind Speed Country Current Description
# 0       20.71      US     overcast clouds
# 1       16.11      CL           clear sky
# 2       11.54      LY     overcast clouds
# 3        7.72      AU     overcast clouds
# 4        6.22      BR     overcast clouds

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     33.03        66         100
# 1  Punta Arenas      CL -53.1500  -70.9167     44.71        70           0
# 2       Awjilah      LY  29.1081   21.2869     70.34        24         100
# 3     Busselton      AU -33.6500  115.3333     69.62        82          99
# 4        Castro      BR -24.7911  -50.0119     55.13        98         100
#
#    Wind Speed Current Description
# 0       20.71     overcast clouds
# 1       16.11           clear sky
# 2       11.54     overcast clouds
# 3        7.72     overcast clouds
# 4        6.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
